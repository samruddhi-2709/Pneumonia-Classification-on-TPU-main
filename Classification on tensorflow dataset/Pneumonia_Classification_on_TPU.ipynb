# %% [markdown]
# **INTRO + SETUP**

# %%
import re
import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
    print("TPU initialized.")
except Exception as e:
    print("Failed to initialize TPU:", str(e))
    strategy = tf.distribute.get_strategy()  # Default strategy with CPU or single GPU
print("Number of replicas:", strategy.num_replicas_in_sync)
# Out:
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.
# TPU initialized.
# Number of replicas: 8

# %%
AUTOTUNE = tf.data.AUTOTUNE
BATCH_SIZE = 25 * strategy.num_replicas_in_sync
IMAGE_SIZE = [180, 180]
CLASS_NAMES = ["NORMAL", "PNEUMONIA"]

# %% [markdown]
# **LOAD THE DATA**

# %%
train_images = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/train/images.tfrec"
)
train_paths = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/train/paths.tfrec"
)

ds = tf.data.Dataset.zip((train_images, train_paths))

# %%
COUNT_NORMAL = len(
    [
        filename
        for filename in train_paths
        if "NORMAL" in filename.numpy().decode("utf-8")
    ]
)
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len(
    [
        filename
        for filename in train_paths
        if "PNEUMONIA" in filename.numpy().decode("utf-8")
    ]
)
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1349
# Pneumonia images count in training set: 3883

# %%
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, "/")
    # The second to last is the class-directory
    if parts[-2] == "PNEUMONIA":
        return 1
    else:
        return 0


def decode_img(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_jpeg(img, channels=3)
    # resize the image to the desired size.
    return tf.image.resize(img, IMAGE_SIZE)


def process_path(image, path):
    label = get_label(path)
    # load the raw data from the file as a string
    img = decode_img(image)
    return img, label


ds = ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
ds = ds.shuffle(10000)
train_ds = ds.take(4200)
val_ds = ds.skip(4200)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  1

# %% [markdown]
# LOAD & FORMAT THE TEST DATA

# %%
test_images = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/test/images.tfrec"
)
test_paths = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/test/paths.tfrec"
)
test_ds = tf.data.Dataset.zip((test_images, test_paths))

test_ds = test_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

# %% [markdown]
# **VISUALATION THE DATASET**

# %%
def prepare_for_training(ds, cache=True):
    # This is a small dataset, only load it once, and keep it in memory.
    # use `.cache(filename)` to cache preprocessing work for datasets that don't
    # fit in memory.
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()

    ds = ds.batch(BATCH_SIZE)

    # `prefetch` lets the dataset fetch batches in the background while the model
    # is training.
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

# %%
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

image_batch, label_batch = next(iter(train_ds))

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10, 10))
    for n in range(25):
        ax = plt.subplot(5, 5, n + 1)
        plt.imshow(image_batch[n] / 255)
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

# %%
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# **BUILD CNN**

# %%
import os
os.environ['KERAS_BACKEND'] = 'tensorflow'

import keras
from keras import layers

def conv_block(filters, inputs):
    x = layers.SeparableConv2D(filters, 3, activation="relu", padding="same")(inputs)
    x = layers.SeparableConv2D(filters, 3, activation="relu", padding="same")(x)
    x = layers.BatchNormalization()(x)
    outputs = layers.MaxPool2D()(x)

    return outputs


def dense_block(units, dropout_rate, inputs):
    x = layers.Dense(units, activation="relu")(inputs)
    x = layers.BatchNormalization()(x)
    outputs = layers.Dropout(dropout_rate)(x)

    return outputs

# %%
def build_model():
    inputs = keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
    x = layers.Rescaling(1.0 / 255)(inputs)
    x = layers.Conv2D(16, 3, activation="relu", padding="same")(x)
    x = layers.Conv2D(16, 3, activation="relu", padding="same")(x)
    x = layers.MaxPool2D()(x)

    x = conv_block(32, x)
    x = conv_block(64, x)

    x = conv_block(128, x)
    x = layers.Dropout(0.2)(x)

    x = conv_block(256, x)
    x = layers.Dropout(0.2)(x)

    x = layers.Flatten()(x)
    x = dense_block(512, 0.7, x)
    x = dense_block(128, 0.5, x)
    x = dense_block(64, 0.3, x)

    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# **CORRECT FOR DATA IMBALANCE**

# %%
initial_bias = np.log([COUNT_PNEUMONIA / COUNT_NORMAL])
print("Initial bias: {:.5f}".format(initial_bias[0]))

TRAIN_IMG_COUNT = COUNT_NORMAL + COUNT_PNEUMONIA
weight_for_0 = (1 / COUNT_NORMAL) * (TRAIN_IMG_COUNT) / 2.0
weight_for_1 = (1 / COUNT_PNEUMONIA) * (TRAIN_IMG_COUNT) / 2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print("Weight for class 0: {:.2f}".format(weight_for_0))
print("Weight for class 1: {:.2f}".format(weight_for_1))
# Out:
# Initial bias: 1.05724
# Weight for class 0: 1.94
# Weight for class 1: 0.67

# %% [markdown]
# **TRAIN THE MODEL**

# %% [markdown]
# **DEFINING CALLBACKS**

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint("xray_model.keras", save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(
    patience=10, restore_best_weights=True
)

# %%
initial_learning_rate = 0.015
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)

# %% [markdown]
# **FIT THE MODEL**

# %%
with strategy.scope():
    model = build_model()

    METRICS = [
        keras.metrics.BinaryAccuracy(),
        keras.metrics.Precision(name="precision"),
        keras.metrics.Recall(name="recall"),
    ]
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
        loss="binary_crossentropy",
        metrics=METRICS,
    )

history = model.fit(
    train_ds,
    epochs=100,
    validation_data=val_ds,
    class_weight=class_weight,
    callbacks=[checkpoint_cb, early_stopping_cb],
)
# Out:
# Epoch 1/100
# 21/21 [==============================] - 35s 572ms/step - loss: 0.5826 - binary_accuracy: 0.6760 - precision: 0.8936 - recall: 0.6437 - val_loss: 9.2988 - val_binary_accuracy: 0.7413 - val_precision: 0.7413 - val_recall: 1.0000
# Epoch 2/100
# 21/21 [==============================] - 3s 152ms/step - loss: 0.2799 - binary_accuracy: 0.8879 - precision: 0.9613 - recall: 0.8858 - val_loss: 18.0578 - val_binary_accuracy: 0.7413 - val_precision: 0.7413 - val_recall: 1.0000
# Epoch 3/100
# 21/21 [==============================] - 4s 192ms/step - loss: 0.2038 - binary_accuracy: 0.9210 - precision: 0.9779 - recall: 0.9150 - val_loss: 4.8135 - val_binary_accuracy: 0.7413 - val_precision: 0.7413 - val_recall: 1.0000
# Epoch 4/100
# 21/21 [==============================] - 4s 191ms/step - loss: 0.1944 - binary_accuracy: 0.9212 - precision: 0.9756 - recall: 0.9176 - val_loss: 3.5416 - val_binary_accuracy: 0.7413 - val_precision: 0.7413 - val_recall: 1.0000
# Epoch 5/100
# 21/21 [==============================] - 4s 190ms/step - loss: 0.1668 - binary_accuracy: 0.9336 - precision: 0.9822 - recall: 0.9281 - val_loss: 2.0406 - val_binary_accuracy: 0.7636 - val_precision: 0.7582 - val_recall: 1.0000
# Epoch 6/100
# 21/21 [==============================] - 3s 152ms/step - loss: 0.1607 - binary_accuracy: 0.9386 - precision: 0.9820 - recall: 0.9351 - val_loss: 2.5780 - val_binary_accuracy: 0.7529 - val_precision: 0.7500 - val_recall: 1.0000
# Epoch 7/100
# 21/21 [==============================] - 3s 153ms/step - loss: 0.1763 - binary_accuracy: 0.9300 - precision: 0.9804 - recall: 0.9249 - val_loss: 11.4347 - val_binary_accuracy: 0.3275 - val_precision: 1.0000 - val_recall: 0.0928
# Epoch 8/100
# 21/21 [==============================] - 3s 154ms/step - loss: 0.1668 - binary_accuracy: 0.9326 - precision: 0.9795 - recall: 0.9294 - val_loss: 15.7846 - val_binary_accuracy: 0.3072 - val_precision: 1.0000 - val_recall: 0.0654
# Epoch 9/100
# 21/21 [==============================] - 3s 154ms/step - loss: 0.1546 - binary_accuracy: 0.9398 - precision: 0.9836 - recall: 0.9351 - val_loss: 5.0826 - val_binary_accuracy: 0.6047 - val_precision: 1.0000 - val_recall: 0.4667
# Epoch 10/100
# 21/21 [==============================] - 4s 216ms/step - loss: 0.1300 - binary_accuracy: 0.9521 - precision: 0.9855 - recall: 0.9500 - val_loss: 0.3641 - val_binary_accuracy: 0.9448 - val_precision: 0.9670 - val_recall: 0.9582
# Epoch 11/100
# 21/21 [==============================] - 3s 153ms/step - loss: 0.1119 - binary_accuracy: 0.9576 - precision: 0.9878 - recall: 0.9551 - val_loss: 0.4478 - val_binary_accuracy: 0.9409 - val_precision: 0.9644 - val_recall: 0.9556
# Epoch 12/100
# 21/21 [==============================] - 3s 152ms/step - loss: 0.1164 - binary_accuracy: 0.9569 - precision: 0.9888 - recall: 0.9532 - val_loss: 1.1893 - val_binary_accuracy: 0.8149 - val_precision: 1.0000 - val_recall: 0.7503
# Epoch 13/100
# 21/21 [==============================] - 3s 150ms/step - loss: 0.1016 - binary_accuracy: 0.9617 - precision: 0.9898 - recall: 0.9586 - val_loss: 0.3790 - val_binary_accuracy: 0.8672 - val_precision: 0.9876 - val_recall: 0.8314
# Epoch 14/100
# 21/21 [==============================] - 4s 189ms/step - loss: 0.0921 - binary_accuracy: 0.9655 - precision: 0.9928 - recall: 0.9609 - val_loss: 0.1458 - val_binary_accuracy: 0.9641 - val_precision: 0.9727 - val_recall: 0.9791
# Epoch 15/100
# 21/21 [==============================] - 3s 153ms/step - loss: 0.0993 - binary_accuracy: 0.9612 - precision: 0.9901 - recall: 0.9577 - val_loss: 0.1713 - val_binary_accuracy: 0.9603 - val_precision: 0.9738 - val_recall: 0.9725
# Epoch 16/100
# 21/21 [==============================] - 3s 153ms/step - loss: 0.0928 - binary_accuracy: 0.9636 - precision: 0.9895 - recall: 0.9615 - val_loss: 0.1703 - val_binary_accuracy: 0.9525 - val_precision: 0.9566 - val_recall: 0.9804
# Epoch 17/100
# 21/21 [==============================] - 3s 150ms/step - loss: 0.1103 - binary_accuracy: 0.9555 - precision: 0.9897 - recall: 0.9504 - val_loss: 1.8163 - val_binary_accuracy: 0.8285 - val_precision: 0.8121 - val_recall: 1.0000
# Epoch 18/100
# 21/21 [==============================] - 4s 177ms/step - loss: 0.0913 - binary_accuracy: 0.9619 - precision: 0.9905 - recall: 0.9583 - val_loss: 0.2617 - val_binary_accuracy: 0.9351 - val_precision: 0.9943 - val_recall: 0.9176
# Epoch 19/100
# 21/21 [==============================] - 3s 155ms/step - loss: 0.0813 - binary_accuracy: 0.9698 - precision: 0.9931 - recall: 0.9663 - val_loss: 0.9904 - val_binary_accuracy: 0.8624 - val_precision: 0.8480 - val_recall: 0.9922
# Epoch 20/100
# 21/21 [==============================] - 3s 156ms/step - loss: 0.0732 - binary_accuracy: 0.9733 - precision: 0.9941 - recall: 0.9701 - val_loss: 0.2638 - val_binary_accuracy: 0.9234 - val_precision: 0.9712 - val_recall: 0.9242
# Epoch 21/100
# 21/21 [==============================] - 4s 191ms/step - loss: 0.0677 - binary_accuracy: 0.9731 - precision: 0.9935 - recall: 0.9704 - val_loss: 0.1212 - val_binary_accuracy: 0.9651 - val_precision: 0.9828 - val_recall: 0.9699
# Epoch 22/100
# 21/21 [==============================] - 4s 193ms/step - loss: 0.0519 - binary_accuracy: 0.9790 - precision: 0.9958 - recall: 0.9761 - val_loss: 0.1169 - val_binary_accuracy: 0.9661 - val_precision: 0.9803 - val_recall: 0.9739
# Epoch 23/100
# 21/21 [==============================] - 3s 152ms/step - loss: 0.0644 - binary_accuracy: 0.9721 - precision: 0.9941 - recall: 0.9685 - val_loss: 0.2202 - val_binary_accuracy: 0.9554 - val_precision: 0.9724 - val_recall: 0.9673
# Epoch 24/100
# 21/21 [==============================] - 3s 151ms/step - loss: 0.0467 - binary_accuracy: 0.9836 - precision: 0.9952 - recall: 0.9828 - val_loss: 0.7328 - val_binary_accuracy: 0.9322 - val_precision: 0.9182 - val_recall: 0.9974
# Epoch 25/100
# 21/21 [==============================] - 3s 152ms/step - loss: 0.0440 - binary_accuracy: 0.9833 - precision: 0.9971 - recall: 0.9806 - val_loss: 0.1450 - val_binary_accuracy: 0.9545 - val_precision: 0.9945 - val_recall: 0.9438
# Epoch 26/100
# 21/21 [==============================] - 4s 182ms/step - loss: 0.0356 - binary_accuracy: 0.9857 - precision: 0.9974 - recall: 0.9835 - val_loss: 0.3757 - val_binary_accuracy: 0.9312 - val_precision: 0.9171 - val_recall: 0.9974
# Epoch 27/100
# 21/21 [==============================] - 3s 152ms/step - loss: 0.0452 - binary_accuracy: 0.9819 - precision: 0.9948 - recall: 0.9809 - val_loss: 0.2121 - val_binary_accuracy: 0.9380 - val_precision: 0.9916 - val_recall: 0.9242
# Epoch 28/100
# 21/21 [==============================] - 4s 192ms/step - loss: 0.0384 - binary_accuracy: 0.9864 - precision: 0.9965 - recall: 0.9854 - val_loss: 0.0916 - val_binary_accuracy: 0.9787 - val_precision: 0.9934 - val_recall: 0.9778
# Epoch 29/100
# 21/21 [==============================] - 4s 191ms/step - loss: 0.0377 - binary_accuracy: 0.9879 - precision: 0.9977 - recall: 0.9860 - val_loss: 0.0834 - val_binary_accuracy: 0.9738 - val_precision: 0.9907 - val_recall: 0.9739
# Epoch 30/100
# 21/21 [==============================] - 3s 152ms/step - loss: 0.0567 - binary_accuracy: 0.9783 - precision: 0.9935 - recall: 0.9774 - val_loss: 0.2321 - val_binary_accuracy: 0.9244 - val_precision: 1.0000 - val_recall: 0.8980
# Epoch 31/100
# 21/21 [==============================] - 3s 151ms/step - loss: 0.0438 - binary_accuracy: 0.9833 - precision: 0.9952 - recall: 0.9825 - val_loss: 0.1889 - val_binary_accuracy: 0.9486 - val_precision: 0.9958 - val_recall: 0.9346
# Epoch 32/100
# 21/21 [==============================] - 3s 153ms/step - loss: 0.0361 - binary_accuracy: 0.9876 - precision: 0.9961 - recall: 0.9873 - val_loss: 0.2256 - val_binary_accuracy: 0.9758 - val_precision: 0.9805 - val_recall: 0.9869
# Epoch 33/100
# 21/21 [==============================] - 3s 152ms/step - loss: 0.0503 - binary_accuracy: 0.9824 - precision: 0.9961 - recall: 0.9803 - val_loss: 0.1136 - val_binary_accuracy: 0.9680 - val_precision: 0.9867 - val_recall: 0.9699
# Epoch 34/100
# 21/21 [==============================] - 3s 154ms/step - loss: 0.0493 - binary_accuracy: 0.9790 - precision: 0.9935 - recall: 0.9784 - val_loss: 0.2919 - val_binary_accuracy: 0.9525 - val_precision: 0.9904 - val_recall: 0.9451
# Epoch 35/100
# 21/21 [==============================] - 3s 155ms/step - loss: 0.0460 - binary_accuracy: 0.9826 - precision: 0.9958 - recall: 0.9809 - val_loss: 0.3512 - val_binary_accuracy: 0.9419 - val_precision: 0.9903 - val_recall: 0.9307
# Epoch 36/100
# 21/21 [==============================] - 3s 155ms/step - loss: 0.0502 - binary_accuracy: 0.9802 - precision: 0.9951 - recall: 0.9784 - val_loss: 0.1652 - val_binary_accuracy: 0.9554 - val_precision: 0.9736 - val_recall: 0.9660
# Epoch 37/100
# 21/21 [==============================] - 3s 156ms/step - loss: 0.0400 - binary_accuracy: 0.9850 - precision: 0.9968 - recall: 0.9831 - val_loss: 0.3573 - val_binary_accuracy: 0.9680 - val_precision: 0.9621 - val_recall: 0.9961
# Epoch 38/100
# 21/21 [==============================] - 3s 150ms/step - loss: 0.0362 - binary_accuracy: 0.9857 - precision: 0.9955 - recall: 0.9854 - val_loss: 0.2439 - val_binary_accuracy: 0.9477 - val_precision: 0.9972 - val_recall: 0.9320
# Epoch 39/100
# 21/21 [==============================] - 8s 390ms/step - loss: 0.0358 - binary_accuracy: 0.9864 - precision: 0.9952 - recall: 0.9866 - val_loss: 0.1535 - val_binary_accuracy: 0.9661 - val_precision: 0.9906 - val_recall: 0.9634

# %% [markdown]
# **VISUALIZING MODEL PERFORMANCE**

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(["precision", "recall", "binary_accuracy", "loss"]):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history["val_" + met])
    ax[i].set_title("Model {}".format(met))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(met)
    ax[i].legend(["train", "val"])

# %% [markdown]
# **PREDICT AND EVALUATE RESULTS**

# %%
model.evaluate(test_ds, return_dict=True)
# Out:
# 4/4 [==============================] - 7s 1s/step - loss: 2.4041 - binary_accuracy: 0.7981 - precision: 0.7640 - recall: 0.9795
# {'loss': 2.4041218757629395,
#  'binary_accuracy': 0.7980769276618958,
#  'precision': 0.7639999985694885,
#  'recall': 0.9794871807098389}

# %%
for image, label in test_ds.take(1):
    plt.imshow(image[0] / 255.0)
    plt.title(CLASS_NAMES[label[0].numpy()])

prediction = model.predict(test_ds.take(1))[0]
scores = [1 - prediction, prediction]

for score, name in zip(scores, CLASS_NAMES):
    print("This image is %.2f percent %s" % ((100 * score), name))
# Out:
# 1/1 [==============================] - 1s 1s/step
# This image is 99.92 percent NORMAL
# This image is 0.08 percent PNEUMONIA
# <ipython-input-23-d4c28b2be0ce>:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("This image is %.2f percent %s" % ((100 * score), name))

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# Class names for visualization
CLASS_NAMES = ["NORMAL", "PNEUMONIA"]

# Function to display images and predictions
def display_images_with_predictions(test_ds, model):
    # Shuffle the dataset to get random samples
    test_ds = test_ds.shuffle(10000)

    # Get two batches of images and labels from the test dataset
    for (image1, label1), (image2, label2) in zip(test_ds.take(1), test_ds.skip(1).take(1)):
        # Display the images side by side
        fig, axes = plt.subplots(1, 2, figsize=(10, 5))

        # Normalize the images for display
        axes[0].imshow(image1[0] / 255.0)
        axes[0].set_title(f"True: {CLASS_NAMES[label1[0].numpy()]}")
        axes[0].axis('off')

        axes[1].imshow(image2[0] / 255.0)
        axes[1].set_title(f"True: {CLASS_NAMES[label2[0].numpy()]}")
        axes[1].axis('off')

        plt.show()

        # Make predictions
        prediction1 = model.predict(tf.expand_dims(image1[0], axis=0))[0][0]
        prediction2 = model.predict(tf.expand_dims(image2[0], axis=0))[0][0]

        scores1 = [1 - prediction1, prediction1]
        scores2 = [1 - prediction2, prediction2]

        # Print the predictions
        for score, name in zip(scores1, CLASS_NAMES):
            print(f"This image is {score * 100:.2f} percent {name}")

        for score, name in zip(scores2, CLASS_NAMES):
            print(f"This image is {score * 100:.2f} percent {name}")

        break

# Example of creating the test dataset (you need to replace this with your actual dataset loading code)
# Assuming you already have test_ds created as shown in the previous explanations
test_images = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/test/images.tfrec"
)
test_paths = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/test/paths.tfrec"
)
test_ds = tf.data.Dataset.zip((test_images, test_paths))

def get_label(file_path):
    parts = tf.strings.split(file_path, "/")
    return 1 if parts[-2] == "PNEUMONIA" else 0

def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3)
    return tf.image.resize(img, IMAGE_SIZE)

def process_path(image, path):
    label = get_label(path)
    img = decode_img(image)
    return img, label

AUTOTUNE = tf.data.AUTOTUNE
BATCH_SIZE = 25
IMAGE_SIZE = [180, 180]

test_ds = test_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

# Example model (replace this with your actual model)
# model = ... (Assume you have your model already defined and trained)

# Display images and predictions
display_images_with_predictions(test_ds, model)
# Out:
# 1/1 [==============================] - 0s 434ms/step
# 1/1 [==============================] - 0s 430ms/step
# This image is 0.00 percent NORMAL
# This image is 100.00 percent PNEUMONIA
# This image is 99.99 percent NORMAL
# This image is 0.01 percent PNEUMONIA
